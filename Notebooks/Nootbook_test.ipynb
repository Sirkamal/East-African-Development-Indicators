# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def clean_world_bank_data(filepath, missing_codes=[".."], 
                           start_year=2010, end_year=2024):
    
    df = pd.read_excel(filepath, sheet_name="Data", dtype=str)
    
    # Filter columns for years
    year_columns = [str(year) for year in range(start_year, end_year + 1)]
    df = df[["Country Name", "Country Code"] + year_columns]
    
    # Replace missing codes with NaN and convert to numeric
    for code in missing_codes:
        df.replace(code, np.nan, inplace=True)
    
    for year in year_columns:
        df[year] = pd.to_numeric(df[year], errors='coerce')
    
    return df

# %%
df_clean= clean_world_bank_data(
    r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicator.xlsx'
)
df_clean.to_csv(r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicator_Cleaned.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_clean= clean_world_bank_data(
#       2     r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicator.xlsx'
#       3 )
#       4 df_clean.to_csv(r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicator_Cleaned.csv', index=False)
#
# Cell In[5], line 4, in clean_world_bank_data(filepath, missing_codes, start_year, end_year)
#       1 def clean_world_bank_data(filepath, missing_codes=[".."],
#       2                            start_year=2010, end_year=2024):
# ----> 4     df = pd.read_excel(filepath, sheet_name="Data", dtype=str)
#       6     # Filter columns for years
# ...

# %%
def clean_world_bank_data(filepath, missing_codes=[".."],
                           start_year=2010, end_year=2024):
    
    # Block 1 - Open the file
    df = pd.read_excel(filepath, sheet_name="Data", dtype=str)
    
    # Block 2 - Remove metadata rows
    valid_countries = [
        "Somalia, Fed. Rep.", "Kenya", "Uganda",
        "South Sudan", "Rwanda", "Congo, Dem. Rep.",
        "Tanzania", "Burundi"
    ]
    df = df[df["Country Name"].isin(valid_countries)]
    df = df.dropna(subset=["Country Name"])

# %%
df_test = clean_world_bank_data(
    r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicator.xlsx'
)

df_test.shape
# Out:
# (40, 20)

# %%
def clean_world_bank_data(filepath, missing_codes=[".."],
                           start_year=2010, end_year=2024):
    
    # Block 1 - Open the file
    df = pd.read_excel(filepath, sheet_name="Data", dtype=str)
    
    # Block 2 - Remove metadata rows
    valid_countries = [
        "Somalia, Fed. Rep.", "Kenya", "Uganda",
        "South Sudan", "Rwanda", "Congo, Dem. Rep.",
        "Tanzania", "Burundi"
    ]
    df = df[df["Country Name"].isin(valid_countries)]
    df = df.dropna(subset=["Country Name"])
    
    # Block 3 - Replace missing codes and fix dtypes
    for code in missing_codes:
        df = df.replace(code, np.nan)
    
    year_cols = [col for col in df.columns if "YR" in col]
    df[year_cols] = df[year_cols].apply(pd.to_numeric, errors="coerce")
    
    return df

# %%
df_test = clean_world_bank_data(
    r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicator.xlsx'
)

df_test.dtypes
# Out:
# C:\Users\abdin\AppData\Local\Temp\ipykernel_15068\3182511190.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(code, np.nan)
# Country Name      object
# Country Code      object
# Series Name       object
# Series Code       object
# 2010 [YR2010]    float64
# 2011 [YR2011]    float64
# 2012 [YR2012]    float64
# 2013 [YR2013]    float64
# 2014 [YR2014]    float64
# 2015 [YR2015]    float64
# 2016 [YR2016]    float64
# 2017 [YR2017]    float64
# 2018 [YR2018]    float64
# 2019 [YR2019]    float64
# 2020 [YR2020]    float64
# 2021 [YR2021]    float64
# 2022 [YR2022]    float64
# 2023 [YR2023]    float64
# 2024 [YR2024]    float64
# 2025 [YR2025]    float64
# dtype: object

# %%
def clean_world_bank_data(filepath, missing_codes=[".."],
                           start_year=2010, end_year=2024):
    
    # Block 1 - Open the file
    df = pd.read_excel(filepath, sheet_name="Data", dtype=str)
    
    # Block 2 - Remove metadata rows
    valid_countries = [
        "Somalia, Fed. Rep.", "Kenya", "Uganda",
        "South Sudan", "Rwanda", "Congo, Dem. Rep.",
        "Tanzania", "Burundi"
    ]
    df = df[df["Country Name"].isin(valid_countries)]
    df = df.dropna(subset=["Country Name"])
    
    # Block 3 - Replace missing codes and fix dtypes
    for code in missing_codes:
        df = df.replace(code, np.nan)
    
    year_cols = [col for col in df.columns if "YR" in col]
    df[year_cols] = df[year_cols].apply(pd.to_numeric, errors="coerce")
    
    # Block 4 - Clean column names and drop outside year range
    df.columns = [col.split(" ")[0] if "YR" in col else col for col in df.columns]
    
    all_years = [str(y) for y in range(2010, 2026)]
    keep_years = [str(y) for y in range(start_year, end_year + 1)]
    drop_years = [y for y in all_years if y not in keep_years]
    df = df.drop(columns=[y for y in drop_years if y in df.columns])
    
    return df

# %%
df_test = clean_world_bank_data(
    r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicator.xlsx'
)

df_test.columns.tolist()
# Out:
# C:\Users\abdin\AppData\Local\Temp\ipykernel_15068\3919494059.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(code, np.nan)
# ['Country Name',
#  'Country Code',
#  'Series Name',
#  'Series Code',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2023',
#  '2024']

# %%
df_test = clean_world_bank_data(
    r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicator.xlsx'
)

df_test.shape
# Out:
# C:\Users\abdin\AppData\Local\Temp\ipykernel_15068\3919494059.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(code, np.nan)
# (40, 19)

# %%
def clean_world_bank_data(filepath, missing_codes=[".."],
                           start_year=2010, end_year=2024):
    
    # Block 1 - Open the file
    df = pd.read_excel(filepath, sheet_name="Data", dtype=str)
    
    # Block 2 - Remove metadata rows
    valid_countries = [
        "Somalia, Fed. Rep.", "Kenya", "Uganda",
        "South Sudan", "Rwanda", "Congo, Dem. Rep.",
        "Tanzania", "Burundi"
    ]
    df = df[df["Country Name"].isin(valid_countries)]
    df = df.dropna(subset=["Country Name"])
    
    # Block 3 - Replace missing codes and fix dtypes
    for code in missing_codes:
        df = df.replace(code, np.nan)
    
    year_cols = [col for col in df.columns if "YR" in col]
    df[year_cols] = df[year_cols].apply(pd.to_numeric, errors="coerce")
    
    # Block 4 - Clean column names and drop outside year range
    df.columns = [col.split(" ")[0] if "YR" in col else col for col in df.columns]
    
    all_years = [str(y) for y in range(2010, 2026)]
    keep_years = [str(y) for y in range(start_year, end_year + 1)]
    drop_years = [y for y in all_years if y not in keep_years]
    df = df.drop(columns=[y for y in drop_years if y in df.columns])
    
    # Block 5 - Reshape from wide to long
    keep_cols = ["Country Name", "Country Code", "Series Name", "Series Code"]
    value_cols = [str(y) for y in range(start_year, end_year + 1)]
    
    df_long = pd.melt(
        df,
        id_vars=keep_cols,
        value_vars=value_cols,
        var_name="Year",
        value_name="Value"
    )
    
    df_long["Year"] = df_long["Year"].astype(int)
    
    return df_long

# %%
df_test = clean_world_bank_data(
    r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicator.xlsx'
)

df_test.shape
# Out:
# C:\Users\abdin\AppData\Local\Temp\ipykernel_15068\3707968317.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(code, np.nan)
# (600, 6)

# %%
def clean_world_bank_data(filepath, missing_codes=[".."],
                           start_year=2010, end_year=2024,
                           save_path=None):
    
    # Block 1 - Open the file
    df = pd.read_excel(filepath, sheet_name="Data", dtype=str)
    
    # Block 2 - Remove metadata rows
    valid_countries = [
        "Somalia, Fed. Rep.", "Kenya", "Uganda",
        "South Sudan", "Rwanda", "Congo, Dem. Rep.",
        "Tanzania", "Burundi"
    ]
    df = df[df["Country Name"].isin(valid_countries)]
    df = df.dropna(subset=["Country Name"])
    
    # Block 3 - Replace missing codes and fix dtypes
    for code in missing_codes:
        df = df.replace(code, np.nan)
    
    year_cols = [col for col in df.columns if "YR" in col]
    df[year_cols] = df[year_cols].apply(pd.to_numeric, errors="coerce")
    
    # Block 4 - Clean column names and drop outside year range
    df.columns = [col.split(" ")[0] if "YR" in col else col for col in df.columns]
    
    all_years = [str(y) for y in range(2010, 2026)]
    keep_years = [str(y) for y in range(start_year, end_year + 1)]
    drop_years = [y for y in all_years if y not in keep_years]
    df = df.drop(columns=[y for y in drop_years if y in df.columns])
    
    # Block 5 - Reshape from wide to long
    keep_cols = ["Country Name", "Country Code", "Series Name", "Series Code"]
    value_cols = [str(y) for y in range(start_year, end_year + 1)]
    
    df_long = pd.melt(
        df,
        id_vars=keep_cols,
        value_vars=value_cols,
        var_name="Year",
        value_name="Value"
    )
    
    df_long["Year"] = df_long["Year"].astype(int)
    
    # Block 6 - Summary and save
    total_cells = df_long["Value"].shape[0]
    missing_cells = df_long["Value"].isna().sum()
    missing_pct = round((missing_cells / total_cells) * 100, 1)
    
    print("=" * 50)
    print("CLEANING SUMMARY")
    print("=" * 50)
    print(f"Final shape      : {df_long.shape}")
    print(f"Total cells      : {total_cells}")
    print(f"Missing values   : {missing_cells} ({missing_pct}%)")
    print("\nMissing by Country-Indicator:")
    missing_summary = (
        df_long[df_long["Value"].isna()]
        .groupby(["Country Name", "Series Name"])
        .size()
        .reset_index(name="Missing Years")
    )
    print(missing_summary.to_string(index=False))
    
    if save_path:
        df_long.to_csv(save_path, index=False)
        print(f"\nSaved to: {save_path}")
    print("=" * 50)
    
    return df_long

# %%
df_clean = clean_world_bank_data(
    filepath=r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicator.xlsx',
    save_path=r'C:\Users\abdin\Desktop\Decision Analysist\Chapter 1 Projects\East African Countries Development Indicators\Data\EAC_Development_Indicators_Clean.csv'
)
# Out:
# ...
# CLEANING SUMMARY
# ...
# Final shape      : (600, 6)
# Total cells      : 600
# Missing values   : 142 (23.7%)
#
# Missing by Country-Indicator:
#       Country Name                                                      Series Name  Missing Years
#            Burundi                            Gross national expenditure (% of GDP)             15
#            Burundi Unemployment, total (% of total labor force) (national estimate)             13
#   Congo, Dem. Rep.                            Inflation, consumer prices (annual %)              8
#   Congo, Dem. Rep. Unemployment, total (% of total labor force) (national estimate)             12
#              Kenya Unemployment, total (% of total labor force) (national estimate)             11
#             Rwanda Unemployment, total (% of total labor force) (national estimate)              5
# Somalia, Fed. Rep.                            Gross national expenditure (% of GDP)              2
# ...
